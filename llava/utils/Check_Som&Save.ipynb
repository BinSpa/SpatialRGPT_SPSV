# %%
import os
from som import *
from pathlib import Path
from datasets import load_dataset

# %%
root = Path("/root/autodl-tmp/spsv/SpatialRGPT-Bench").expanduser().resolve()
ds = load_dataset(str(root), split="val")

print(ds)
index = 100
print("columns:", ds.column_names)
print("id:", ds[120]['id'])
print("image_info:", ds[120]['image_info'])
print("qa_info:", ds[120]['qa_info'])
print("text_q:", ds[120]['text_q'])
print("concersation type:", type(ds[120]['conversations'][0]))
print("concersation:", ds[120]['conversations'])
example_image = ds[120]['image']
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].imshow(example_image)
axes[0].set_title('Original Image')
axes[0].axis('off')

axes[1].imshow(example_image)
axes[1].set_title(f"SoM annotated sample")
axes[1].axis('off')
# Out:
# Dataset({
#     features: ['id', 'image_info', 'qa_info', 'conversations', 'text_q', 'bbox', 'rle', 'image'],
#     num_rows: 1406
# })
# columns: ['id', 'image_info', 'qa_info', 'conversations', 'text_q', 'bbox', 'rle', 'image']
# id: quantitative_PKHJ3yyJtl
# image_info: {'height': 1920, 'width': 1440, 'dataset': 'ARKitScenes', 'landmark': 'indoor', 'file_path': 'ARKitScenes/Validation/42446100/77925.290_00001117.jpg'}
# qa_info: {'type': 'quantitative', 'category': 'height_data', 'class': ['shelves']}
# text_q: What is the approximate height of Region [0]?
# concersation type: <class 'str'>
# concersation: [{'from': 'human', 'value': '\n What is the approximate height of <mask>?'}, {'from': 'gpt', 'value': '38.71 inches'}]
# (np.float64(-0.5), np.float64(1439.5), np.float64(1919.5), np.float64(-0.5))

# %%
som_visualize_one(
    ds,
    120,
    "/root/autodl-tmp/spsv/SpatialRGPT-Bench",
    show=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1440x1920>

# %%
from tqdm import tqdm
# 把som图像保存
for i in tqdm(range(len(ds))):
    som_visualize_one(
        ds,
        i,
        base_path = "/root/autodl-tmp/spsv/SpatialRGPT-Bench",
        out_dir = "/root/autodl-tmp/spsv/SpatialRGPT-Bench/som_images",
        show=False)
# Out:
#   0%|                                                                               | 1/1406 [00:00<22:19,  1.05it/s]
# [saved] /root/autodl-tmp/spsv/SpatialRGPT-Bench/som_images/qualitative_3TrgWgKqnf.png
#   0%|                                                                             | 2/1406 [00:07<1:37:48,  4.18s/it]
# [saved] /root/autodl-tmp/spsv/SpatialRGPT-Bench/som_images/quantitative_L1Nt6oLYo9.png
#   0%|▏                                                                              | 3/1406 [00:07<56:20,  2.41s/it]
# [saved] /root/autodl-tmp/spsv/SpatialRGPT-Bench/som_images/qualitative_owIPR7rMKZ.png
#   0%|▏                                                                            | 4/1406 [00:11<1:08:00,  2.91s/it]
# [saved] /root/autodl-tmp/spsv/SpatialRGPT-Bench/som_images/quantitative_2stayVjLa3.png
#   0%|▎                                                                            | 5/1406 [00:13<1:05:33,  2.81s/it]
# ...
